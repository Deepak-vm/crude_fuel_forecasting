# %%
# Importing the required libraries
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("//home//deepak//4th semester//ML//Project//dataset//crude-oil-price.csv")

# %%
df.head(10)
# Out:
#                   date  price  percentChange  change
# 0  1983-03-30T00:00:00  29.27            NaN     NaN
# 1  1983-04-04T00:00:00  30.63          4.646    1.36
# 2  1983-05-02T00:00:00  30.25         -1.241   -0.38
# 3  1983-06-01T00:00:00  31.38          3.736    1.13
# 4  1983-07-01T00:00:00  32.00          1.976    0.62
# 5  1983-08-01T00:00:00  31.59         -1.281   -0.41
# 6  1983-09-01T00:00:00  30.36         -3.894   -1.23
# 7  1983-10-03T00:00:00  30.37          0.033    0.01
# 8  1983-11-01T00:00:00  29.23         -3.754   -1.14
# 9  1983-12-01T00:00:00  29.60          1.266    0.37

# %%
df.dtypes
# Out:
# date              object
# price            float64
# percentChange    float64
# change           float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], utc=True)

# %%
df.dtypes
# Out:
# date             datetime64[ns, UTC]
# price                        float64
# percentChange                float64
# change                       float64
# dtype: object

# %% [markdown]
# Data Visualization

# %%
plt.figure(figsize = (10,8))
sns.lineplot(data=df, x = 'date', y = 'price')
plt.title('Crude Oil Price Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
print("Before Null values in the dataset:")
print(df.isnull().sum())
# Out:
# Before Null values in the dataset:
# date             0
# price            0
# percentChange    1
# change           1
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
print("After Null values in the dataset:")
print(df.isnull().sum())
# Out:
# After Null values in the dataset:
# date             0
# price            0
# percentChange    0
# change           0
# dtype: int64
